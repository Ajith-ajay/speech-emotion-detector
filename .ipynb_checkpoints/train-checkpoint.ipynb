# %%
# %pip install librosa soundfile numpy scikit-learn pyaudio
# Out:
# Collecting librosa
#   Using cached librosa-0.11.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting soundfile
#   Using cached soundfile-0.13.1-py2.py3-none-win_amd64.whl.metadata (16 kB)
# Requirement already satisfied: numpy in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (1.6.1)
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp310-cp310-win_amd64.whl.metadata (2.7 kB)
# Collecting audioread>=2.1.9 (from librosa)
#   Downloading audioread-3.0.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting numba>=0.51.0 (from librosa)
#   Downloading numba-0.61.2-cp310-cp310-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from librosa) (1.15.2)
# Requirement already satisfied: joblib>=1.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from librosa) (5.2.1)
# Collecting pooch>=1.1 (from librosa)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting soxr>=0.3.2 (from librosa)
#   Downloading soxr-0.5.0.post1-cp310-cp310-win_amd64.whl.metadata (5.6 kB)
# Requirement already satisfied: typing_extensions>=4.1.1 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from librosa) (4.12.2)
# Collecting lazy_loader>=0.1 (from librosa)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting msgpack>=1.0 (from librosa)
#   Downloading msgpack-1.1.1-cp310-cp310-win_amd64.whl.metadata (8.6 kB)
# Requirement already satisfied: cffi>=1.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from soundfile) (1.17.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: pycparser in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from lazy_loader>=0.1->librosa) (24.2)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.51.0->librosa)
#   Downloading llvmlite-0.44.0-cp310-cp310-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ajith g\anaconda3\envs\genderclass\lib\site-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2025.1.31)
# Downloading librosa-0.11.0-py3-none-any.whl (260 kB)
# Downloading soundfile-0.13.1-py2.py3-none-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    ---------------------------------------- 1.0/1.0 MB 5.4 MB/s eta 0:00:00
# Downloading PyAudio-0.2.14-cp310-cp310-win_amd64.whl (164 kB)
# Downloading audioread-3.0.1-py3-none-any.whl (23 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading msgpack-1.1.1-cp310-cp310-win_amd64.whl (71 kB)
# Downloading numba-0.61.2-cp310-cp310-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    ------------------ --------------------- 1.3/2.8 MB 6.7 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 6.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 5.7 MB/s eta 0:00:00
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Downloading soxr-0.5.0.post1-cp310-cp310-win_amd64.whl (166 kB)
# Downloading llvmlite-0.44.0-cp310-cp310-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.3/30.3 MB 7.4 MB/s eta 0:00:04
#    --- ------------------------------------ 2.6/30.3 MB 7.2 MB/s eta 0:00:04
#    ----- ---------------------------------- 3.9/30.3 MB 6.2 MB/s eta 0:00:05
#    ------- -------------------------------- 5.5/30.3 MB 6.6 MB/s eta 0:00:04
#    -------- ------------------------------- 6.3/30.3 MB 6.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 7.6/30.3 MB 6.2 MB/s eta 0:00:04
#    ----------- ---------------------------- 8.9/30.3 MB 6.0 MB/s eta 0:00:04
#    ------------- -------------------------- 10.2/30.3 MB 6.1 MB/s eta 0:00:04
#    -------------- ------------------------- 11.3/30.3 MB 5.8 MB/s eta 0:00:04
#    ---------------- ----------------------- 12.6/30.3 MB 5.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 13.4/30.3 MB 5.7 MB/s eta 0:00:03
#    ------------------- -------------------- 14.4/30.3 MB 5.6 MB/s eta 0:00:03
#    -------------------- ------------------- 15.7/30.3 MB 5.8 MB/s eta 0:00:03
#    ---------------------- ----------------- 17.0/30.3 MB 5.7 MB/s eta 0:00:03
#    ----------------------- ---------------- 17.6/30.3 MB 5.6 MB/s eta 0:00:03
#    ------------------------ --------------- 18.6/30.3 MB 5.4 MB/s eta 0:00:03
#    ------------------------- -------------- 19.1/30.3 MB 5.3 MB/s eta 0:00:03
#    ------------------------- -------------- 19.7/30.3 MB 5.1 MB/s eta 0:00:03
#    --------------------------- ------------ 20.7/30.3 MB 5.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 21.8/30.3 MB 5.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 22.5/30.3 MB 5.0 MB/s eta 0:00:02
#    ------------------------------- -------- 23.6/30.3 MB 5.0 MB/s eta 0:00:02
#    ------------------------------- -------- 23.9/30.3 MB 5.0 MB/s eta 0:00:02
#    -------------------------------- ------- 24.6/30.3 MB 4.8 MB/s eta 0:00:02
#    ---------------------------------- ----- 26.0/30.3 MB 4.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 27.3/30.3 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------- -- 28.3/30.3 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 28.8/30.3 MB 4.8 MB/s eta 0:00:01
#    -------------------------------------- - 29.1/30.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------  29.9/30.3 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 4.6 MB/s eta 0:00:00
# Installing collected packages: pyaudio, soxr, msgpack, llvmlite, lazy_loader, audioread, soundfile, pooch, numba, librosa
# Successfully installed audioread-3.0.1 lazy_loader-0.4 librosa-0.11.0 llvmlite-0.44.0 msgpack-1.1.1 numba-0.61.2 pooch-1.8.2 pyaudio-0.2.14 soundfile-0.13.1 soxr-0.5.0.post1
# Note: you may need to restart the kernel to use updated packages.

# %%
import librosa
import soundfile
import os, glob, pickle
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # DataFlair - Extract features (mfcc, chroma, mel) from a sound file
# - mfcc: Mel Frequency Cepstral Coefficient, represents the short-term power spectrum of a sound
# - mel: Mel Spectrogram Frequency
# -
# chroma: Pertains to the 12 different pitch classscy

# %%
def extract_feature(file_name, mfcc, chroma, mel):
    with soundfile.SoundFile(file_name) as sound_file:
        X = sound_file.read(dtype="float32")
        sample_rate=sound_file.samplerate
        if chroma:
            stft=np.abs(librosa.stft(X))
        result=np.array([])
        if mfcc:
            mfccs=np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T, axis=0)
            result=np.hstack((result, mfccs))
        if chroma:
            chroma=np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T,axis=0)
            result=np.hstack((result, chroma))
        if mel:
            mel = np.mean(librosa.feature.melspectrogram(y=X, sr=sample_rate).T, axis=0)
            result=np.hstack((result, mel))
    return result

# %%
#DataFlair - Emotions in the RAVDESS dataset
emotions={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

#DataFlair - Emotions to observe
observed_emotions=['calm', 'happy', 'fearful', 'disgust']

# %%
#DataFlair - Load the data and extract features for each sound file
def load_data(test_size=0.2):
    x,y=[],[]
    for file in glob.glob("D:\\Projects\\Machine Learning\\speech emotion detector\\data\\Actor_*\\*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions[file_name.split("-")[2]]
        if emotion not in observed_emotions:
            continue
        feature=extract_feature(file, mfcc=True, chroma=True, mel=True)
        x.append(feature)
        y.append(emotion)
    return train_test_split(np.array(x), y, test_size=test_size, random_state=9)

# %%
#DataFlair - Split the dataset
x_train,x_test,y_train,y_test=load_data(test_size=0.25)

# %%
x_train.shape[0]
# Out:
# 576

# %%
x_test.shape[0]
# Out:
# 192

# %%
print(f'Features extracted: {x_train.shape[1]}')
# Out:
# Features extracted: 180

# %% [markdown]
# ### Initialize the Multi Layer Perceptron Classifier
# - Regularization strength (to avoid overfitting)
# - Number of training samples used in one step
# - Small number to improve numerical stability
# - One hidden layer with 300 neurons
# - Adjusts learning rate if the model stops improving
# - Maximum number of training cycles (epochs)

# %%
model=MLPClassifier(
    alpha=0.01, 
    batch_size=256, 
    epsilon=1e-08, 
    hidden_layer_sizes=(300,), 
    learning_rate='adaptive', 
    max_iter=500
)

# %%
model.fit(x_train,y_train)
# Out:
# MLPClassifier(alpha=0.01, batch_size=256, hidden_layer_sizes=(300,),
#               learning_rate='adaptive', max_iter=500)

# %%
y_pred = model.predict(x_test)

# %%
accuracy=accuracy_score(y_true=y_test, y_pred=y_pred)

print("Accuracy: {:.2f}%".format(accuracy*100))
# Out:
# Accuracy: 69.27%

# %%
def predict_emotion(file_path):
    feature = extract_feature(file_path, mfcc=True, chroma=True, mel=True)
    # feature = scaler.transform([feature])
    prediction = model.predict([feature])
    return prediction[0]

# Example
print(predict_emotion("D:\\Projects\\Machine Learning\\speech emotion detector\\test\\sad.wav"))
# Out:
# happy

# %%
import pickle

with open("model.pkl", "wb") as f:
    pickle.dump(model, f)
